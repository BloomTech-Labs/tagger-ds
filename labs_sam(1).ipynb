# %%
# This is the cell where we do all the imports
import os
import boto3
import re
import copy
import time
from time import gmtime, strftime
from sagemaker import get_execution_role
from sklearn.model_selection import train_test_split
import pandas as pd
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from nltk.tokenize.regexp import regexp_tokenize
import category_encoders as ce
import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Connecting to an s3 bucket
role = get_execution_role()

region = boto3.Session().region_name

bucket='sagemaker-samuel'
prefix = 'sagemaker/nlp-email'
bucket_path = 'https://s3-{}.amazonaws.com/{}'.format(region,bucket)

# %%
# Pull in the csv
emails = pd.read_csv('update_twelve_three.csv')
emails.head()
# Out:
#                                             From  \
# 0      <grangepayments@westernunionspeedpay.com>
# 1              Chase <no.reply.alerts@chase.com>
# 2  Amazon Web Services <no-reply-aws@amazon.com>
# 3               Lambda Labs <noreply@github.com>
# 4  Amazon Web Services <no-reply-aws@amazon.com>
#
#                                              Message  \
# 0  Dear AVRAHAM JACOBSOHN,  This is to confirm th...
# 1   This is an Alert to help manage your account ...
# 2  Please let us know if we helped resolve your i...
# 3  Youve been added to the Labs 18 - Tagger team ...
# 4   Hello,  We haven't heard back from you regard...
#
#                                              Subject          Tags    UID  \
# 0                        Grange Payment Confirmation       Finance  31780
# 1                        Your Debit Card Transaction       Finance  31779
# 2     Resolved 6559329691: Limit Increase: SageMaker  Productivity  31738
# 3  Bernie Durfee added you to the Lambda Labs tea...  Productivity  31693
# 4  Attention required on case 6559329691: Limit I...  Productivity  31684
#
#                                                 text          tag_list  \
# 0  <grangepayments@westernunionspeedpay.com> Gran...       ['Finance']
# 1  Chase <no.reply.alerts@chase.com> Your Debit C...       ['Finance']
# 2  Amazon Web Services <no-reply-aws@amazon.com> ...  ['Productivity']
# 3  Lambda Labs <noreply@github.com> Bernie Durfee...  ['Productivity']
# 4  Amazon Web Services <no-reply-aws@amazon.com> ...  ['Productivity']
#
#       first_tag          sender_name                             sender_email  \
# 0       Finance                  NaN  grangepayments@westernunionspeedpay.com
# 1       Finance                Chase                no.reply.alerts@chase.com
# 2  Productivity  Amazon Web Services                  no-reply-aws@amazon.com
# 3  Productivity          Lambda Labs                       noreply@github.com
# 4  Productivity  Amazon Web Services                  no-reply-aws@amazon.com
#
#             domain_name  isNoReply
# 0  westernunionspeedpay      False
# 1                 chase       True
# 2                amazon       True
# 3                github       True
# 4                amazon       True

# %%
# Take the columns we want
emails = emails[['sender_email', 'Message', 'Subject', 'Tags', 'UID', 'first_tag']]
emails.tail()
# Out:
#                                  sender_email  \
# 11193                      noreply@medium.com
# 11194                   noreply@glassdoor.com
# 11195  aws-marketing-email-replies@amazon.com
# 11196                 no-reply-aws@amazon.com
# 11197                      noreply@medium.com
#
#                                                  Message  \
# 11193  Today's highlights    Understanding Random For...
# 11194                                                ...
# 11195  Thank you for attending AWS Machine Learning W...
# 11196    Hello again,     I hope you're having a nice...
# 11197  Today's highlights    How To Wake Up at 5 A.M....
#
#                                                  Subject  \
# 11193  Understanding Random Forest | Tony Yiu in Towa...
# 11194  You look like a good fit for the job at Procte...
# 11195  Thank you for attending AWS Machine Learning W...
# 11196     RE:[CASE 6570793521] Limit Increase: SageMaker
# 11197  How To Wake Up at 5 A.M. Every Day | Bryan Ye ...
#
#                        Tags   UID      first_tag
# 11193         Entertainment  3693  Entertainment
# 11194          Productivity  3702   Productivity
# 11195  Events, Productivity  3706         Events
# 11196          Productivity  3721   Productivity
# 11197         Entertainment  3724  Entertainment

# %%
# Make sure all the columns we want to be strings are strings
emails['Message'] = emails['Message'].apply(str)
emails['sender_email'] = emails['sender_email'].apply(str)
emails['Subject'] = emails['Subject'].apply(str)
emails['Tags'] = emails['Tags'].apply(str)
emails['first_tag'] = emails['first_tag'].apply(str)

# %%
# Check out all the unique tags
emails['first_tag'].value_counts()
# Out:
# Finance          5678
# Entertainment    1636
# Other            1199
# Shopping         1179
# Productivity     1031
# Events            199
# Social            154
# Travel            122
# Name: first_tag, dtype: int64

# %%
# A little feature engineering to spice things up
emails['Text'] = emails['sender_email'] + ' ' + emails['Message'] + ' ' + emails['Subject']

# %%
# emails[['First_Tag','Second_Tag']] = emails['Tags'].str.split(',', expand=True)
# emails.tail()

# %%
# Make like a banana and split
train, test = train_test_split(emails, stratify=emails['first_tag'])

# %%
# 2's a party and four is a crowd
X_train = train['Text']
y_train = train['first_tag']

X_test = test['Text']
y_test = test['first_tag']

# %%
# A function that removes all unnecessary puncuation, html code, and/or any apostrophes lying around
def clean_text(text):
    # replace new line and carriage return with space
    text = text.replace("\n", " ").replace("\r", " ")
    
    # replace the numbers and punctuation (exclude single quote) with space
    punc_list = '!"#$%&()*+,-/:;<=>?[\]^_{|}~' + '0123456789'
    t = str.maketrans(dict.fromkeys(punc_list, " "))
    text = text.translate(t)
    
    # replace single quote with empty character
    t = str.maketrans(dict.fromkeys("''", ""))
    text = text.translate(t)
    
    return text

# %%
# The lemmatizer
lemmatizer = WordNetLemmatizer()

# nltk's regexp tokenizer mixed with our personal clean_text function
def regnltk_tokenize(text):
    text = clean_text(text)
    words = regexp_tokenize(text, pattern = '\s+', gaps = True)
    return [lemmatizer.lemmatize(word) for word in words if (len(word) >= 3)]

# %%
# gensim's stopwords mixed with a few I added
my_stopwords = STOPWORDS.union(set(['jacobsohn', 'avraham', 'http', 'https', 'kalman', 'com', 'sdui', 'www']))

# %%
# Vectorize the X's with the regex tokenize and my_stopwords
vect = TfidfVectorizer(tokenizer=regnltk_tokenize, stop_words=my_stopwords, min_df=0.02, max_df=0.98)
X_train = vect.fit_transform(X_train)
X_test = vect.transform(X_test)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['doe', 'ha', 'le', 'wa'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
# encode the y's so the computer understands
encoder = ce.OrdinalEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %%
model = RandomForestClassifier(n_estimators=500, max_depth=7, random_state=42)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# 0.8471428571428572

# %%
preds = model.predict(X_test)
df = pd.DataFrame({'Predictions': preds})
df['Predictions'].value_counts()
# Out:
# 2    1347
# 5     603
# 3     369
# 4     248
# 1     233
# Name: Predictions, dtype: int64

# %%
test['preds'] = preds
test.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                    sender_email  \
# 1807         ksemail7@gmail.com
# 7509        no-reply@amazon.com
# 1742  austin@successpodcast.com
# 1547     chave@designsbyfmc.com
# 5493        no-reply@amazon.com
#
#                                                 Message  \
# 1807  youre a doll, thanx :*\n\nOn Thu, Apr 15, 2010...
# 7509  Greetings from Amazon Payments,\n\n\nYour paym...
# 1742  ( https://el2.convertkit-mail2.com/c/r8ul08o5q...
# 1547  You are such a big boy.\n\n-----Original Messa...
# 5493  Greetings from Amazon Payments,\n\n\nYou recei...
#
#                                                 Subject             Tags  \
# 1807                                                Re:  Personal, Other
# 7509                                  Payment completed          Finance
# 1742  A Beginner's Guide To Body Language & Nonverba...    Entertainment
# 1547  RE: Did you have a chance to finish that one d...  Personal, Other
# 5493  You received $1.00 from Kalman Jacobsohn sent ...          Finance
#
#         UID      first_tag                                               Text  \
# 1807   3137          Other  ksemail7@gmail.com youre a doll, thanx :*\n\nO...
# 7509  28432        Finance  no-reply@amazon.com Greetings from Amazon Paym...
# 1742  63232  Entertainment  austin@successpodcast.com ( https://el2.conver...
# 1547   2634          Other  chave@designsbyfmc.com You are such a big boy....
# 5493  25508        Finance  no-reply@amazon.com Greetings from Amazon Paym...
#
#       preds
# 1807      4
# 7509      2
# 1742      5
# 1547      4
# 5493      2

# %%
test.head(50)
# Out:
#                      sender_email  \
# 1807           ksemail7@gmail.com
# 7509          no-reply@amazon.com
# 1742    austin@successpodcast.com
# 1547       chave@designsbyfmc.com
# 5493          no-reply@amazon.com
# 3537          no-reply@amazon.com
# 7347          no-reply@amazon.com
# 3366          no-reply@amazon.com
# 9605              deals@jdeal.com
# 9366            news@linkedin.com
# 9524              deals@jdeal.com
# 8263              deals@jdeal.com
# 159       quincy@freecodecamp.org
# 147    no-reply@alertsp.chase.com
# 5137          no-reply@amazon.com
# 8623         shop@e.nordstrom.com
# 7140          no-reply@amazon.com
# 9681              deals@jdeal.com
# 8956              deals@jdeal.com
# 6448          no-reply@amazon.com
# 1291       support@pokerstars.com
# 7018          no-reply@amazon.com
# 3195          no-reply@amazon.com
# 6440          no-reply@amazon.com
# 5932          no-reply@amazon.com
# 1298       support@pokerstars.com
# 8057     matt@scienceofsuccess.co
# 4775          no-reply@amazon.com
# 10782       cmgrauert@hotmail.com
# 4943          no-reply@amazon.com
# 521    no-reply@alertsp.chase.com
# 10569          no-reply@jibble.io
# 9510              deals@jdeal.com
# 935      noreply@smarter-apps.com
# 2779          no-reply@amazon.com
# 3375          no-reply@amazon.com
# 10488  tampa@verticalventures.com
# 6224          no-reply@amazon.com
# 8576        media@pocketfives.com
# 3551          no-reply@amazon.com
# 7505          no-reply@amazon.com
# 6215          no-reply@amazon.com
# 8224              deals@jdeal.com
# 6272          no-reply@amazon.com
# 1551       support@pokerstars.com
# 10296  stryker@marketing.jobs.net
# 5969          no-reply@amazon.com
# 276    no-reply@alertsp.chase.com
# 4241          no-reply@amazon.com
# 3654          no-reply@amazon.com
#
#                                                  Message  \
# 1807   youre a doll, thanx :*\n\nOn Thu, Apr 15, 2010...
# 7509   Greetings from Amazon Payments,\n\n\nYour paym...
# 1742   ( https://el2.convertkit-mail2.com/c/r8ul08o5q...
# 1547   You are such a big boy.\n\n-----Original Messa...
# 5493   Greetings from Amazon Payments,\n\n\nYou recei...
# 3537   Greetings from Amazon Payments,\n\n\nYour paym...
# 7347   Greetings from Amazon Payments,\n\n\nYour paym...
# 3366   Greetings from Amazon Payments,\n\n\nYou recei...
# 9605   Its a jdeal!\r\n\r\nDonate Thermal Clothing to...
# 9366   The week's most popular news:=20\r\n----------...
# 9524   Its a jdeal!\r\n\r\n$15 for $30 towards dinner...
# 8263   You're receiving this newsletter because you s...
# 159    Here are this week's five links that are worth...
# 147     This is an Alert to help manage your account ...
# 5137   Greetings from Amazon Payments,\n\n\nYou recei...
# 8623   Lightweight, on-trend jackets for work and bey...
# 7140   Greetings from Amazon Payments,\n\n\nYour paym...
# 9681   Its a jdeal!\r\n\r\n$49 Orchestra Ticket to =E...
# 8956   Amazing deals from jdeal.com\r\nAct quickly, t...
# 6448   Greetings from Amazon Payments,\n\n\nYour paym...
# 1291   \nPokerStars Tournament #252010377, No Limit H...
# 7018   Greetings from Amazon Payments,\n\n\nYour paym...
# 3195   Greetings from Amazon Payments,\n\n\nYou recei...
# 6440   Greetings from Amazon Payments,\n\n\nYour paym...
# 5932   Greetings from Amazon Payments,\n\n\nYour paym...
# 1298   \nPokerStars Tournament #231292018, No Limit H...
# 8057   Avraham\n\n\nCheck out the latest episode of T...
# 4775   Greetings from Amazon Payments,\n\n\nYou recei...
# 10782  Tm8gcHJvYiwgYnJvIQ0KSSdtIGEgbGF0ZS1uaWdodGVyIG...
# 4943   Greetings from Amazon Payments,\n\n\nYou recei...
# 521     This is an Alert to help manage your account ...
# 10569  <!DOCTYPE html>\r\n<html>\r\n    <head>\r\n   ...
# 9510   Its a jdeal!\r\n\r\nMake a $9 donation to Met ...
# 935    Hello!  This message was sent because you down...
# 2779   Greetings from Amazon Payments,\n\n\nYou recei...
# 3375   Greetings from Amazon Payments,\n\n\nYou recei...
# 10488  Thank you for visiting Vertical Ventures | Tam...
# 6224   Greetings from Amazon Payments,\n\n\nYour paym...
# 8576   \r\n\r\nhttp://e2ma.net/map/view=CampaignPubli...
# 3551   Greetings from Amazon Payments,\n\n\nYour paym...
# 7505   Greetings from Amazon Payments,\n\n\nYour paym...
# 6215   Greetings from Amazon Payments,\n\n\nYour paym...
# 8224   ==============================================...
# 6272   Greetings from Amazon Payments,\n\n\nYour paym...
# 1551   \nPokerStars Tournament #251451891, No Limit H...
# 10296  <html dir=3D"ltr"><body><div style=3D"display:...
# 5969   Greetings from Amazon Payments,\n\n\nYour paym...
# 276     This is an Alert to help manage your account ...
# 4241   Greetings from Amazon Payments,\n\n\nYour paym...
# 3654   Greetings from Amazon Payments,\n\n\nYour paym...
#
#                                                  Subject  \
# 1807                                                 Re:
# 7509                                   Payment completed
# 1742   A Beginner's Guide To Body Language & Nonverba...
# 1547   RE: Did you have a chance to finish that one d...
# 5493   You received $1.00 from Kalman Jacobsohn sent ...
# 3537                                   Payment completed
# 7347                                   Payment completed
# 3366   You received $1.00 from Kalman Jacobsohn sent ...
# 9605     Protect our soldiers from sub zero temperatures
# 9366   Top news today: Charles Best: How One Teacher ...
# 9524       Authentic Uzbec Israeli food...got to try it.
# 8263   =?utf-8?Q?8=20NIGHTS=20OF=20GIVING=3A=20Suppor...
# 159    Harvard's CS50 Intro to Computer Science cours...
# 147     An Alert from Chase about Your External Transfer
# 5137   You received $1.00 from Kalman Jacobsohn sent ...
# 8623           The 4 Spring Coats Every Woman Should Own
# 7140                                   Payment completed
# 9681   =?UTF8?Q?$49_Orchestra_Ticket_to_=E2=80=9CMy_N...
# 8956   =?utf-8?Q?Great=20Deals=20Expiring=20=2D=20Don...
# 6448                                   Payment completed
# 1291         Results for PokerStars Tournament 252010377
# 7018                                   Payment completed
# 3195   You received $1.00 from Kalman Jacobsohn sent ...
# 6440                                   Payment completed
# 5932                                   Payment completed
# 1298         Results for PokerStars Tournament 231292018
# 8057   The Secret of How Sound Can Make You Be Happie...
# 4775   You received $1.00 from Kalman Jacobsohn sent ...
# 10782                                    Re: CSS 161 lab
# 4943   You received $1.00 from Kalman Jacobsohn sent ...
# 521     An Alert from Chase about Your External Transfer
# 10569              Jibbled In Reminder for Lambda School
# 9510   8 Nights of Giving: Support Met Council and ma...
# 935            Thanks for downloading Player For YouTube
# 2779   You received $1.00 from Kalman Jacobsohn sent ...
# 3375   You received $1.00 from Kalman Jacobsohn sent ...
# 10488           Thank you from Vertical Ventures | Tampa
# 6224                                   Payment completed
# 8576          It's March Madness at P5s - Get a New iPad
# 3551                                   Payment completed
# 7505                                   Payment completed
# 6215                                   Payment completed
# 8224   =?utf-8?Q?$29.99=20for=203=20bottles=20of=20Ta...
# 6272                                   Payment completed
# 1551         Results for PokerStars Tournament 251451891
# 10296  Jobs near Jacksonville, Florida at Stryker Cor...
# 5969                                   Payment completed
# 276                                  Your ATM Withdrawal
# 4241        Your payment to Kalman Jacobsohn has failed.
# 3654                                   Payment completed
#
#                          Tags    UID      first_tag  \
# 1807          Personal, Other   3137          Other
# 7509                  Finance  28432        Finance
# 1742            Entertainment  63232  Entertainment
# 1547          Personal, Other   2634          Other
# 5493                  Finance  25508        Finance
# 3537                  Finance  23258        Finance
# 7347                  Finance  28270        Finance
# 3366                  Finance  23027        Finance
# 9605                 Shopping   3179       Shopping
# 9366                   Social   2815         Social
# 9524                 Shopping   3054       Shopping
# 8263                 Shopping   1290       Shopping
# 159              Productivity  26372   Productivity
# 147                   Finance  26887        Finance
# 5137                  Finance  25152        Finance
# 8623                 Shopping   1785       Shopping
# 7140                  Finance  28060        Finance
# 9681                 Shopping   3310       Shopping
# 8956                 Shopping   2260       Shopping
# 6448                  Finance  26515        Finance
# 1291            Entertainment   1787  Entertainment
# 7018                  Finance  27938        Finance
# 3195                  Finance  22815        Finance
# 6440                  Finance  26507        Finance
# 5932                  Finance  25998        Finance
# 1298            Entertainment   1806  Entertainment
# 8057            Entertainment  55927  Entertainment
# 4775                  Finance  24790        Finance
# 10782  Personal, Productivity  14862   Productivity
# 4943                  Finance  24958        Finance
# 521                   Finance  15778        Finance
# 10569                 Finance   1815        Finance
# 9510                 Shopping   3037       Shopping
# 935             Entertainment    376  Entertainment
# 2779                  Finance  22314        Finance
# 3375                  Finance  23036        Finance
# 10488                Shopping   1734       Shopping
# 6224                  Finance  26291        Finance
# 8576            Entertainment   1723  Entertainment
# 3551                  Finance  23273        Finance
# 7505                  Finance  28428        Finance
# 6215                  Finance  26281        Finance
# 8224                 Shopping   1239       Shopping
# 6272                  Finance  26339        Finance
# 1551            Entertainment   2649  Entertainment
# 10296            Productivity   1542   Productivity
# 5969                  Finance  26035        Finance
# 276                   Finance  22861        Finance
# 4241                  Finance  24067        Finance
# 3654                  Finance  23377        Finance
#
#                                                     Text  preds
# 1807   ksemail7@gmail.com youre a doll, thanx :*\n\nO...      4
# 7509   no-reply@amazon.com Greetings from Amazon Paym...      2
# 1742   austin@successpodcast.com ( https://el2.conver...      5
# 1547   chave@designsbyfmc.com You are such a big boy....      4
# 5493   no-reply@amazon.com Greetings from Amazon Paym...      2
# 3537   no-reply@amazon.com Greetings from Amazon Paym...      2
# 7347   no-reply@amazon.com Greetings from Amazon Paym...      2
# 3366   no-reply@amazon.com Greetings from Amazon Paym...      2
# 9605   deals@jdeal.com Its a jdeal!\r\n\r\nDonate The...      1
# 9366   news@linkedin.com The week's most popular news...      5
# 9524   deals@jdeal.com Its a jdeal!\r\n\r\n$15 for $3...      1
# 8263   deals@jdeal.com You're receiving this newslett...      1
# 159    quincy@freecodecamp.org Here are this week's f...      5
# 147    no-reply@alertsp.chase.com  This is an Alert t...      2
# 5137   no-reply@amazon.com Greetings from Amazon Paym...      2
# 8623   shop@e.nordstrom.com Lightweight, on-trend jac...      1
# 7140   no-reply@amazon.com Greetings from Amazon Paym...      2
# 9681   deals@jdeal.com Its a jdeal!\r\n\r\n$49 Orches...      1
# 8956   deals@jdeal.com Amazing deals from jdeal.com\r...      1
# 6448   no-reply@amazon.com Greetings from Amazon Paym...      2
# 1291   support@pokerstars.com \nPokerStars Tournament...      3
# 7018   no-reply@amazon.com Greetings from Amazon Paym...      2
# 3195   no-reply@amazon.com Greetings from Amazon Paym...      2
# 6440   no-reply@amazon.com Greetings from Amazon Paym...      2
# 5932   no-reply@amazon.com Greetings from Amazon Paym...      2
# 1298   support@pokerstars.com \nPokerStars Tournament...      3
# 8057   matt@scienceofsuccess.co Avraham\n\n\nCheck ou...      5
# 4775   no-reply@amazon.com Greetings from Amazon Paym...      2
# 10782  cmgrauert@hotmail.com Tm8gcHJvYiwgYnJvIQ0KSSdt...      5
# 4943   no-reply@amazon.com Greetings from Amazon Paym...      2
# 521    no-reply@alertsp.chase.com  This is an Alert t...      2
# 10569  no-reply@jibble.io <!DOCTYPE html>\r\n<html>\r...      5
# 9510   deals@jdeal.com Its a jdeal!\r\n\r\nMake a $9 ...      1
# 935    noreply@smarter-apps.com Hello!  This message ...      5
# 2779   no-reply@amazon.com Greetings from Amazon Paym...      2
# 3375   no-reply@amazon.com Greetings from Amazon Paym...      2
# 10488  tampa@verticalventures.com Thank you for visit...      5
# 6224   no-reply@amazon.com Greetings from Amazon Paym...      2
# 8576   media@pocketfives.com \r\n\r\nhttp://e2ma.net/...      3
# 3551   no-reply@amazon.com Greetings from Amazon Paym...      2
# 7505   no-reply@amazon.com Greetings from Amazon Paym...      2
# 6215   no-reply@amazon.com Greetings from Amazon Paym...      2
# 8224   deals@jdeal.com ==============================...      1
# 6272   no-reply@amazon.com Greetings from Amazon Paym...      2
# 1551   support@pokerstars.com \nPokerStars Tournament...      3
# 10296  stryker@marketing.jobs.net <html dir=3D"ltr"><...      5
# 5969   no-reply@amazon.com Greetings from Amazon Paym...      2
# 276    no-reply@alertsp.chase.com  This is an Alert t...      2
# 4241   no-reply@amazon.com Greetings from Amazon Paym...      2
# 3654   no-reply@amazon.com Greetings from Amazon Paym...      2

# %%
test['first_tag'].value_counts()
# Out:
# Finance          1420
# Entertainment     409
# Other             300
# Shopping          295
# Productivity      258
# Events             50
# Social             38
# Travel             30
# Name: first_tag, dtype: int64

# %%
train['first_tag'].value_counts()
# Out:
# Finance          4258
# Entertainment    1227
# Other             899
# Shopping          884
# Productivity      773
# Events            149
# Social            116
# Travel             92
# Name: first_tag, dtype: int64
